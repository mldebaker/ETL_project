# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
import csv

# %% [markdown]
# # User Comparison

# %% [markdown]
# ### Import Raw Data

# %%
# Import User List
file = r"Raw-Data\UserList.csv"

# Read File to Pandas
userlist_raw = pd.read_csv(file)

# Read File into DataFrame
userlist_raw = pd.DataFrame(userlist_raw)

# Display Data
userlist_raw.head()
# Out:
#            username  user_id  user_watching  user_completed  user_onhold  \
# 0          karthiga  2255153              3              49            1
# 1  RedvelvetDaisuki  1897606             61             396           39
# 2         Damonashu    37326             45             195           27
# 3             bskai   228342             25             414            2
# 4         shuzzable  2347781             36              72           16
#
#    user_dropped  user_plantowatch  user_days_spent_watching  gender  \
# 0             0                 0                     55.31  Female
# 1             0               206                    118.07  Female
# 2            25                59                     83.70    Male
# 3             5                11                    167.16    Male
# 4             2                25                     35.48     NaN
#
#            location  birth_date  access_rank   join_date          last_online  \
# 0   Chennai, India   1990-04-29          NaN  2013-03-03  2014-02-04 01:32:00
# 1            Manila  1995-01-01          NaN  2012-12-13  1900-05-13 02:47:00
# 2  Detroit,Michigan  1991-08-01          NaN  2008-02-13  1900-03-24 12:48:00
# 3   Nayarit, Mexico  1990-12-14          NaN  2009-08-31  2014-05-12 16:35:00
# 4               NaN         NaN          NaN  2013-03-25  2015-09-09 21:54:00
#
#    stats_mean_score  stats_rewatched  stats_episodes
# 0              7.43              0.0          3391.0
# 1              6.78             80.0          7094.0
# 2              6.15              6.0          4936.0
# 3              8.27              1.0         10081.0
# 4              9.06              7.0          2154.0

# %% [markdown]
# ### Create Master User Table

# %%
# Create Master User Table
master_user_table = userlist_raw.loc[:, ["user_id","username","user_watching","user_completed",
                                         "user_days_spent_watching","gender","stats_episodes"]].dropna()

# Set index
master_user_table.set_index("user_id", inplace=True)

# Display Table
master_user_table.head()
# Out:
#                  username  user_watching  user_completed  \
# user_id
# 2255153          karthiga              3              49
# 1897606  RedvelvetDaisuki             61             396
# 37326           Damonashu             45             195
# 228342              bskai             25             414
# 327311     terune_uzumaki              5               5
#
#          user_days_spent_watching  gender  stats_episodes
# user_id
# 2255153                     55.31  Female          3391.0
# 1897606                    118.07  Female          7094.0
# 37326                       83.70    Male          4936.0
# 228342                     167.16    Male         10081.0
# 327311                      15.20  Female           920.0

# %% [markdown]
# ### Create Gender Master Tables

# %%
# Create Male Watcher Table
male_userdata = master_user_table.loc[master_user_table.gender == 'Male']

# Set index
male_userdata.set_index("user_id", inplace=True)

# Display Data
male_userdata.head()
# Out:
#             username  user_watching  user_completed  user_days_spent_watching  \
# user_id
# 37326      Damonashu             45             195                     83.70
# 228342         bskai             25             414                    167.16
# 5015094        Bas_G             35             114                     30.81
# 102436    sprite1989           2583             102                     30.86
# 28328    thetreedude             11             703                    206.68
#
#         gender  stats_episodes
# user_id
# 37326     Male          4936.0
# 228342    Male         10081.0
# 5015094   Male          1847.0
# 102436    Male          1829.0
# 28328     Male         12458.0

# %%
# Create Female Watcher Table
female_userdata = master_user_table.loc[master_user_table.gender == 'Female']

# Set index
female_userdata.set_index("user_id", inplace=True)

# Display Data
female_userdata.head()
# Out:
#                  username  user_watching  user_completed  \
# user_id
# 2255153          karthiga              3              49
# 1897606  RedvelvetDaisuki             61             396
# 327311     terune_uzumaki              5               5
# 3129315          HimeAria              2              87
# 2485327     MistButterfly             66            3923
#
#          user_days_spent_watching  gender  stats_episodes
# user_id
# 2255153                     55.31  Female          3391.0
# 1897606                    118.07  Female          7094.0
# 327311                      15.20  Female           920.0
# 3129315                     20.12  Female          1314.0
# 2485327                    614.96  Female         39893.0

# %%
# Create Non-Binary Watcher Table
non_binary_userdata = master_user_table.loc[master_user_table.gender == 'Non-Binary']

# Set index
non_binary_userdata.set_index("user_id", inplace=True)

# Display Data
non_binary_userdata.head()
# Out:
#             username  user_watching  user_completed  user_days_spent_watching  \
# user_id
# 300808      kendolli             33             217                     82.87
# 620011    Myrmidon83              2             209                     50.20
# 3936989  AwasakiYumi              8              76                     26.91
# 4669393     Ketsukos             14             263                    186.97
# 6023468        Zakew              2              33                     10.58
#
#              gender  stats_episodes
# user_id
# 300808   Non-Binary          4849.0
# 620011   Non-Binary          3040.0
# 3936989  Non-Binary          1637.0
# 4669393  Non-Binary         12017.0
# 6023468  Non-Binary           633.0

# %% [markdown]
# ### Gender Statistics

# %%
# Create User Count
user_count = master_user_table['user_id'].count()

# Create Total Days Watched
user_days_watched = master_user_table['user_days_spent_watching'].sum()

# Create Total Episodes Watched
user_episodes_watched = master_user_table['stats_episodes'].sum()

# %%
# Create Male Count
male_count = male_userdata['user_id'].count()

# Create Percentage Male
male_percent = ((male_count / user_count) * 100).round(2)

# Create total Days Watching Male
male_days = male_userdata['user_days_spent_watching'].sum()

# Create Percentage total Days Watching Male
male_days_percent = ((male_days / user_days_watched) * 100).round(2)

# Create Total Episodes Watched Male
male_episodes_watched = male_userdata['stats_episodes'].sum()

# Create Percentage Total Episodes Watched Male
male_episodes_percent = ((male_episodes_watched / user_episodes_watched) * 100).round(2)

# %%
# Create Female Count
female_count = female_userdata['user_id'].count()

# Create Percentage Female
female_percent = ((female_count / user_count) * 100).round(2)

# Create Total Days Watching Female
female_days = female_userdata['user_days_spent_watching'].sum()

# Create Percentage Total Days Watching Female
female_days_percent = ((female_days / user_days_watched) * 100).round(2)

# Create Total Episodes Watched Female
female_episodes_watched = female_userdata['stats_episodes'].sum()

# Create Percentage Total Days Watching Female
female_episodes_percent = ((female_episodes_watched / user_episodes_watched) * 100).round(2)

# %%
# Create Non-Binary Count
non_binary_count = non_binary_userdata['user_id'].count()

# Create Percentage Non-Binary
non_binary_percent = ((non_binary_count / user_count) * 100).round(2)

# Create Total Days Watching Non-Binary
non_binary_days = non_binary_userdata['user_days_spent_watching'].sum()

# Create Percentage Total Days Watching Non-Binary
non_binary_days_percentage = ((non_binary_days / user_days_watched) * 100).round(2)

# Create Total Episodes Watched Non-Binary
non_binary_episodes_watched = non_binary_userdata['stats_episodes'].sum()

# Create Percentage Total Episodes Watched Non-Binary
non_binary_episodes_percentage = ((non_binary_episodes_watched / user_episodes_watched) * 100).round(2)

# %%
# Create Gender Statistics Table
index = ["Male", "Female", "Non_Binary"]

gender_statistics = [
    {
        'user_count':male_count,
        'user_percent':male_percent,
        'days_watched':male_days,
        'percent_of_days_watched':male_days_percent,
        'total_episodes_watched':male_episodes_watched,
        'total_episodes_percent':male_episodes_percent        
    },
    {
        'user_count':female_count,
        'user_percent':female_percent,
        'days_watched':female_days,
        'percent_of_days_watched':female_days_percent,
        'total_episodes_watched':female_episodes_watched,
        'total_episodes_percent':female_episodes_percent
    },
    {
        'user_count':non_binary_count,
        'user_percent':non_binary_percent,
        'days_watched':non_binary_days,
        'percent_of_days_watched':non_binary_days_percentage,
        'total_episodes_watched':non_binary_episodes_watched,
        'total_episodes_percent':non_binary_episodes_percentage 
    }
]

gender_statistics = pd.DataFrame(gender_statistics, index=index)
gender_statistics.index.name='gender'
gender_statistics
# Out:
#             days_watched  percent_of_days_watched  total_episodes_percent  \
# gender
# Male         12931604.21                    75.04                   77.70
# Female        4197862.11                    24.36                   21.71
# Non_Binary     102767.53                     0.60                    0.60
#
#             total_episodes_watched  user_count  user_percent
# gender
# Male                   949792696.0      135180         62.07
# Female                 265340842.0       81374         37.36
# Non_Binary               7296834.0        1245          0.57

# %%
for col in gender_statistics.columns: 
    print(col)
# Out:
# days_watched
# percent_of_days_watched
# total_episodes_percent
# total_episodes_watched
# user_count
# user_percent

# %% [markdown]
# # Anime Comparison

# %%
# Import User List
file = r"Raw-Data\AnimeList.csv"

# Read File to Pandas
animelist_raw = pd.read_csv(file)

# Read File into DataFrame
animelist_raw = pd.DataFrame(animelist_raw)

# Display Data
animelist_raw.head()
# Out:
#    anime_id                title              title_english title_japanese  \
# 0     11013        Inu x Boku SS  Inu X Boku Secret Service         妖狐×僕SS
# 1      2104     Seto no Hanayome      My Bride is a Mermaid          瀬戸の花嫁
# 2      5262   Shugo Chara!! Doki         Shugo Chara!! Doki    しゅごキャラ！！どきっ
# 3       721        Princess Tutu              Princess Tutu      プリンセスチュチュ
# 4     12365  Bakuman. 3rd Season                   Bakuman.          バクマン。
#
#                                   title_synonyms  \
# 0                                Youko x Boku SS
# 1                           The Inland Sea Bride
# 2  Shugo Chara Ninenme, Shugo Chara! Second Year
# 3                                            NaN
# 4                               Bakuman Season 3
#
#                                            image_url type    source  episodes  \
# 0  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        12
# 1  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        26
# 2  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        51
# 3  https://myanimelist.cdn-dena.com/images/anime/...   TV  Original        38
# 4  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        25
#
#             status  ...                                         background  \
# 0  Finished Airing  ...  Inu x Boku SS was licensed by Sentai Filmworks...
# 1  Finished Airing  ...                                                NaN
# 2  Finished Airing  ...                                                NaN
# 3  Finished Airing  ...  Princess Tutu aired in two parts. The first pa...
# 4  Finished Airing  ...                                                NaN
#
#      premiered           broadcast  \
# 0  Winter 2012  Fridays at Unknown
# 1  Spring 2007             Unknown
# 2    Fall 2008             Unknown
# 3  Summer 2002  Fridays at Unknown
# 4    Fall 2012             Unknown
#
#                                              related  \
# 0  {'Adaptation': [{'mal_id': 17207, 'type': 'man...
# 1  {'Adaptation': [{'mal_id': 759, 'type': 'manga...
# 2  {'Adaptation': [{'mal_id': 101, 'type': 'manga...
# 3  {'Adaptation': [{'mal_id': 1581, 'type': 'mang...
# 4  {'Adaptation': [{'mal_id': 9711, 'type': 'mang...
#
#                                             producer          licensor  \
# 0  Aniplex, Square Enix, Mainichi Broadcasting Sy...  Sentai Filmworks
# 1                  TV Tokyo, AIC, Square Enix, Sotsu        Funimation
# 2                                    TV Tokyo, Sotsu               NaN
# 3                 Memory-Tech, GANSIS, Marvelous AQL         ADV Films
# 4                                      NHK, Shueisha               NaN
#
#              studio                                     genre  \
# 0  David Production    Comedy, Supernatural, Romance, Shounen
# 1             Gonzo  Comedy, Parody, Romance, School, Shounen
# 2         Satelight             Comedy, Magic, School, Shoujo
# 3    Hal Film Maker    Comedy, Drama, Magic, Romance, Fantasy
# 4         J.C.Staff           Comedy, Drama, Romance, Shounen
#
#                                        opening_theme  \
# 0                              ['"Nirvana" by MUCC']
# 1                 ['"Romantic summer" by SUN&LUNAR']
# 2  ['#1: "Minna no Tamago (みんなのたまご)" by Shugo Cha...
# 3             ['"Morning Grace" by Ritsuko Okazaki']
# 4  ['#1: "Moshimo no Hanashi (もしもの話)" by nano.RIP...
#
#                                         ending_theme
# 0  ['#1: "Nirvana" by MUCC (eps 1, 11-12)', '#2: ...
# 1  ['#1: "Ashita e no Hikari (明日への光)" by Asuka Hi...
# 2  ['#1: "Rottara Rottara (ロッタラ ロッタラ)" by Buono! ...
# 3  ['"Watashi No Ai Wa Chiisaikeredo" by Ritsuko ...
# 4  ['#1: "Pride on Everyday" by Sphere (eps 1-13)...
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Master Anime Table

# %%
# Create Master Anime Table
master_anime_table = animelist_raw.loc[:, ["anime_id","title","title_english","title_japanese",
                                          "title_synonyms","type", "source", "episodes",
                                           "status","premiered","producer","licensor",
                                           "studio","genre","score","scored_by","rank"]]
# Set index
master_anime_table.set_index("anime_id", inplace=True)

# Display Table
master_anime_table.head()
# Out:
#                         title              title_english title_japanese  \
# anime_id
# 11013           Inu x Boku SS  Inu X Boku Secret Service         妖狐×僕SS
# 2104         Seto no Hanayome      My Bride is a Mermaid          瀬戸の花嫁
# 5262       Shugo Chara!! Doki         Shugo Chara!! Doki    しゅごキャラ！！どきっ
# 721             Princess Tutu              Princess Tutu      プリンセスチュチュ
# 12365     Bakuman. 3rd Season                   Bakuman.          バクマン。
#
#                                          title_synonyms type    source  \
# anime_id
# 11013                                   Youko x Boku SS   TV     Manga
# 2104                               The Inland Sea Bride   TV     Manga
# 5262      Shugo Chara Ninenme, Shugo Chara! Second Year   TV     Manga
# 721                                                 NaN   TV  Original
# 12365                                  Bakuman Season 3   TV     Manga
#
#           episodes           status    premiered  \
# anime_id
# 11013           12  Finished Airing  Winter 2012
# 2104            26  Finished Airing  Spring 2007
# 5262            51  Finished Airing    Fall 2008
# 721             38  Finished Airing  Summer 2002
# 12365           25  Finished Airing    Fall 2012
#
#                                                    producer          licensor  \
# anime_id
# 11013     Aniplex, Square Enix, Mainichi Broadcasting Sy...  Sentai Filmworks
# 2104                      TV Tokyo, AIC, Square Enix, Sotsu        Funimation
# 5262                                        TV Tokyo, Sotsu               NaN
# 721                      Memory-Tech, GANSIS, Marvelous AQL         ADV Films
# 12365                                         NHK, Shueisha               NaN
#
#                     studio                                     genre  score  \
# anime_id
# 11013     David Production    Comedy, Supernatural, Romance, Shounen   7.63
# 2104                 Gonzo  Comedy, Parody, Romance, School, Shounen   7.89
# 5262             Satelight             Comedy, Magic, School, Shoujo   7.55
# 721         Hal Film Maker    Comedy, Drama, Magic, Romance, Fantasy   8.21
# 12365            J.C.Staff           Comedy, Drama, Romance, Shounen   8.67
#
#           scored_by    rank
# anime_id
# 11013        139250  1274.0
# 2104          91206   727.0
# 5262          37129  1508.0
# 721           36501   307.0
# 12365        107767    50.0

# %% [markdown]
# ### Anime Based On Manga Table

# %%
# Create Anime From Manga Table
anime_from_manga = master_anime_table.loc[master_anime_table.source == 'Manga']

# Display Data
anime_from_manga.head()
# Out:
#                         title              title_english title_japanese  \
# anime_id
# 11013           Inu x Boku SS  Inu X Boku Secret Service         妖狐×僕SS
# 2104         Seto no Hanayome      My Bride is a Mermaid          瀬戸の花嫁
# 5262       Shugo Chara!! Doki         Shugo Chara!! Doki    しゅごキャラ！！どきっ
# 12365     Bakuman. 3rd Season                   Bakuman.          バクマン。
# 6586      Yume-iro Pâtissière                        NaN      夢色パティシエール
#
#                                              title_synonyms type source  \
# anime_id
# 11013                                       Youko x Boku SS   TV  Manga
# 2104                                   The Inland Sea Bride   TV  Manga
# 5262          Shugo Chara Ninenme, Shugo Chara! Second Year   TV  Manga
# 12365                                      Bakuman Season 3   TV  Manga
# 6586      Yumeiro Patissiere, YumePati, Dream-Colored Pa...   TV  Manga
#
#           episodes           status    premiered  \
# anime_id
# 11013           12  Finished Airing  Winter 2012
# 2104            26  Finished Airing  Spring 2007
# 5262            51  Finished Airing    Fall 2008
# 12365           25  Finished Airing    Fall 2012
# 6586            50  Finished Airing    Fall 2009
#
#                                                    producer          licensor  \
# anime_id
# 11013     Aniplex, Square Enix, Mainichi Broadcasting Sy...  Sentai Filmworks
# 2104                      TV Tokyo, AIC, Square Enix, Sotsu        Funimation
# 5262                                        TV Tokyo, Sotsu               NaN
# 12365                                         NHK, Shueisha               NaN
# 6586          Yomiuri Telecasting, DAX Production, Shueisha               NaN
#
#                                  studio  \
# anime_id
# 11013                  David Production
# 2104                              Gonzo
# 5262                          Satelight
# 12365                         J.C.Staff
# 6586      Studio Pierrot, Studio Hibari
#
#                                              genre  score  scored_by    rank
# anime_id
# 11013       Comedy, Supernatural, Romance, Shounen   7.63     139250  1274.0
# 2104      Comedy, Parody, Romance, School, Shounen   7.89      91206   727.0
# 5262                 Comedy, Magic, School, Shoujo   7.55      37129  1508.0
# 12365              Comedy, Drama, Romance, Shounen   8.67     107767    50.0
# 6586                          Kids, School, Shoujo   8.03      21618   526.0

# %% [markdown]
# ### User Ratings

# %%
# Create Ratings Table
user_ratings_table = animelist_raw.loc[:, ["anime_id","title","title_english","score",
                                           "scored_by","rank"]]
# Set index
user_ratings_table.set_index("anime_id", inplace=True)

# Display Data
user_ratings_table.head()
# Out:
#                         title              title_english  score  scored_by  \
# anime_id
# 11013           Inu x Boku SS  Inu X Boku Secret Service   7.63     139250
# 2104         Seto no Hanayome      My Bride is a Mermaid   7.89      91206
# 5262       Shugo Chara!! Doki         Shugo Chara!! Doki   7.55      37129
# 721             Princess Tutu              Princess Tutu   8.21      36501
# 12365     Bakuman. 3rd Season                   Bakuman.   8.67     107767
#
#             rank
# anime_id
# 11013     1274.0
# 2104       727.0
# 5262      1508.0
# 721        307.0
# 12365       50.0

# %%
# Create engine and connection
connection_string = "postgres:#Md716902@localhost:5432/ETL-Project"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Create user ratings table info in pgadmin
user_ratings_table.to_sql(name='user_ratings', con=engine, if_exists='append', index=True)

# %%
# Create manga anime table info in pgadmin
anime_from_manga.to_sql(name='manga_anime', con=engine, if_exists='append', index=True)

# %%
# Create master anime table info in pgadmin
master_anime_table.to_sql(name='master_anime', con=engine, if_exists='append', index=True)

# %%
# Create gender statistics table info in pgadmin
gender_statistics.to_sql(name='gender_statistics', con=engine, if_exists='append', index=True)

# %%
# Create gender non binary table info in pgadmin
non_binary_userdata.to_sql(name='gender_non_binary', con=engine, if_exists='append', index=True)

# %%
# Create gender female table info in pgadmin
female_userdata.to_sql(name='gender_female', con=engine, if_exists='append', index=True)

# %%
# Create gender male table info in pgadmin
male_userdata.to_sql(name='gender_male', con=engine, if_exists='append', index=True)

# %%
# Create master user info in pgadmin
master_user_table.to_sql(name='master_user', con=engine, if_exists='append', index=True)

# %%
# Confirm tables "evidence of success"
engine.table_names()
# Out:
# ['gender_statistics',
#  'gender_non_binary',
#  'gender_female',
#  'user_ratings',
#  'manga_anime',
#  'master_anime',
#  'gender_male',
#  'master_user']
